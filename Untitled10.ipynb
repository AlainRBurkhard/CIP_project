# %%
from selenium import webdriver

driver = webdriver.Firefox()

# Set the path to your GeckoDriver (e.g., geckodriver)
driver = webdriver.Firefox(executable_path='/opt/homebrew/bin/geckodriver')

# Open a website
driver.get('https://www.google.com')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       3 driver = webdriver.Firefox()
#       5 # Set the path to your GeckoDriver (e.g., geckodriver)
# ----> 6 driver = webdriver.Firefox(executable_path='/opt/homebrew/bin/geckodriver')
#       8 # Open a website
#       9 driver.get('https://www.google.com')
#
# TypeError: WebDriver.__init__() got an unexpected keyword argument 'executable_path'

# %%
help(webdriver.Firefox)
# Out:
# Help on class WebDriver in module selenium.webdriver.firefox.webdriver:
#
# class WebDriver(selenium.webdriver.remote.webdriver.WebDriver)
#  |  WebDriver(options: selenium.webdriver.firefox.options.Options = None, service: selenium.webdriver.firefox.service.Service = None, keep_alive: bool = True) -> None
#  |
#  |  Controls the GeckoDriver and allows you to drive the browser.
#  |
#  |  Method resolution order:
#  |      WebDriver
#  |      selenium.webdriver.remote.webdriver.WebDriver
#  |      selenium.webdriver.remote.webdriver.BaseWebDriver
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, options: selenium.webdriver.firefox.options.Options = None, service: selenium.webdriver.firefox.service.Service = None, keep_alive: bool = True) -> None
#  |      Creates a new instance of the Firefox driver. Starts the service and
#  |      then creates new instance of Firefox driver.
#  |
#  |      :Args:
# ...

# %%
opt = selenium.webdriver.firefox.options.Options()

# %%
import selenium

# %%
help(opt)
# Out:
# Help on Options in module selenium.webdriver.firefox.options object:
#
# class Options(selenium.webdriver.common.options.ArgOptions)
#  |  Options() -> None
#  |
#  |  Method resolution order:
#  |      Options
#  |      selenium.webdriver.common.options.ArgOptions
#  |      selenium.webdriver.common.options.BaseOptions
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self) -> None
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  enable_mobile(self, android_package: str = 'org.mozilla.firefox', android_activity=None, device_serial=None)
#  |      Enables mobile browser use for browsers that support it.
#  |
#  |      :Args:
#  |          android_activity: The name of the android package to start
#  |
#  |  set_preference(self, name: str, value: Union[str, int, bool])
#  |      Sets a preference.
#  |
#  |  to_capabilities(self) -> dict
#  |      Marshals the Firefox options to a `moz:firefoxOptions` object.
#  |
# ...

# %%
opt.binary_location = '/opt/homebrew/bin/geckodriver'

# %%
driver = webdriver.Firefox(options = opt)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 driver = webdriver.Firefox(options = opt)
#
# File ~/anaconda3/lib/python3.11/site-packages/selenium/webdriver/firefox/webdriver.py:59, in WebDriver.__init__(self, options, service, keep_alive)
#      56 self.service = service if service else Service()
#      57 options = options if options else Options()
# ---> 59 self.service.path = DriverFinder.get_path(self.service, options)
#      60 self.service.start()
#      62 executor = FirefoxRemoteConnection(
#      63     remote_server_addr=self.service.service_url,
#      64     keep_alive=keep_alive,
#      65     ignore_proxy=options._ignore_local_proxy,
#      66 )
#
# File ~/anaconda3/lib/python3.11/site-packages/selenium/webdriver/common/driver_finder.py:38, in DriverFinder.get_path(service, options)
#      36 path = service.path
#      37 try:
# ...
