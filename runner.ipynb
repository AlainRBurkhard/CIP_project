# %% [markdown]
# # Script Runner

# %% [markdown]
# ### Stage 01 - Scraping

# %%
# %run stage01_mediamarkt_scraping.py
# Out:
# 2024-04-15 22:23:45,787 - WARNING -  phone['webpage'] ='https://www.mediamarkt.ch/de/product/_apple-iphone-15-2203373.html'
# 2024-04-15 22:23:45,791 - WARNING -  css_selector ='div[itemprop="ratingValue"]'
# 2024-04-15 22:23:45,792 - WARNING - Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:192:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:510:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# 2024-04-15 22:24:10,344 - WARNING -  phone['webpage'] ='https://www.mediamarkt.ch/de/product/_apple-iphone-13-2118876.html'
# 2024-04-15 22:24:10,345 - WARNING -  css_selector ='div[itemprop="ratingValue"]'
# 2024-04-15 22:24:10,345 - WARNING - Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:192:5
# ...

# %% [markdown]
# ### Stage 02 - Cleaning

# %%
# %run stage02_mediamarkt_cleaning.py
# Out:
# /Users/ramonburkhard/CIP_project/stage02_mediamarkt_cleaning.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['category'] = df['category'].str.lower() #Transforming all data in column to lowercase
# /Users/ramonburkhard/CIP_project/stage02_mediamarkt_cleaning.py:188: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.25' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['webpage'] == url, 'size'] = size
# /Users/ramonburkhard/CIP_project/stage02_mediamarkt_cleaning.py:251: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# ### Stage 03 - Transforming

# %%
# %run stage03_mediamarkt_transformation.py
